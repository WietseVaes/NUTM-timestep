# %%
include("..\\Code_jail\\Master_func.jl")
# Out:
# SpecialFunction (generic function with 2 methods)

# %%
w = -[-2,-9,5,-1,-4,1,3];
xx = 2;
tt = 0.00001;
DD = FullPath(w, xx+eps(), tt);
DomainPlot(DD)
NumericalDomainPlot(DD)

# %%
#w = -[-1/2 2 5];
w=  [0,0,0,-1];
xx = 0.0001;
tt = 0.00001;
DD = FullPath(w, xx+eps(), tt);
DomainPlot(DD)
NumericalDomainPlot(DD)

# %%
w = [0, 0, 0, 1];
xx = 2;
tt = 10^(-12);
DD =  FullPath(w, xx+eps(), tt);
DomainPlot(DD)
NumericalDomainPlot(DD)

# %%
w = [1];
xx = 2;
tt = 1;
DD =  FullPath(w, xx+eps(), 1im*tt);
DomainPlot(DD)
NumericalDomainPlot(DD)

# %%
w = [1]
N = 200;
m = 1;

funt = (x,t) -> SpecialFunction(w, x, t, m, N);
Solu = (x,t) -> -exp(-x^2/(4*t))*sqrt(pi)*x/(2*t^(3/2));

L = 2
Nt = 10;
Nx = 101;
T = 0.0001
tt = T/(Nt):T/(Nt):T
xx = -L:2*L/(Nx-1):L

Qsol = Complex.(zeros(length(xx),length(tt)))
Rsol = Complex.(zeros(length(xx),length(tt)))
for i2 = 1:Nt
    Qsol[:,i2] = map(x->funt(x,tt[i2]),xx)
    Rsol[:,i2] = map(x->Solu(x,tt[i2]),xx)
end
surface(tt,xx, abs.(Qsol-Rsol) .+ 1e-16,camera = (45, 45), xlabel = "t", ylabel = "x")

# %%
w = [1]
N = 200;
m = 2;

funt = (x,t) -> SpecialFunction(w, x, t, m, N);
Solu = (x,t) -> -exp(-x^2/(4*t))*sqrt(pi)*(2*t-x^2)/(4*t^(5/2));

L = 2
Nt = 10;
Nx = 101;
T = 0.0001
tt = T/(Nt):T/(Nt):T
xx = -L:2*L/(Nx-1):L

Qsol = Complex.(zeros(length(xx),length(tt)))
Rsol = Complex.(zeros(length(xx),length(tt)))
for i2 = 1:Nt
    Qsol[:,i2] = map(x->funt(x,tt[i2]),xx)
    Rsol[:,i2] = map(x->Solu(x,tt[i2]),xx)
end
surface(tt,xx, abs.(Qsol-Rsol) .+ 1e-16,camera = (45, 45), xlabel = "t", ylabel = "x")

# %%
w = [1]
N = 200;
m = 3;

funt = (x,t) -> SpecialFunction(w, x, t, m, N);
Solu = (x,t) -> -exp(-x^2/(4*t))*sqrt(pi)*x*(-6*t+x^2)/(8*t^(7/2));

L = 2
Nt = 10;
Nx = 100;
T = 0.0001
tt = T/(Nt):T/(Nt):T
xx = -L:2*L/(Nx-1):L

Qsol = Complex.(zeros(length(xx),length(tt)))
Rsol = Complex.(zeros(length(xx),length(tt)))
for i2 = 1:Nt
    Qsol[:,i2] = map(x->funt(x,tt[i2]),xx)
    Rsol[:,i2] = map(x->Solu(x,tt[i2]),xx)
end
surface(tt,xx, abs.(Qsol-Rsol) .+ 1e-16,camera = (45, 45), xlabel = "t", ylabel = "x")

# %%
using SpecialFunctions
x = -4:.1:4
w = [1]
N = 200;
m = -1;

funt = x -> SpecialFunction(w, x, 1, m, N);
plot(x,real.(funt.(x))/(2*pi)+erfc.(x ./ 2)/2)
